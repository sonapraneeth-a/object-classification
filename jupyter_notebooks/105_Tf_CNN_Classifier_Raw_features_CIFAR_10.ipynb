# %% [markdown]
# ## Make necessary imports

# %%
import sys
sys.path.insert(0, '../')

# %%
import time
import numpy as np
np.set_printoptions(precision=3, linewidth=200, suppress=True)
import tensorflow as tf

# %%
from library.datasets.cifar10 import CIFAR10
from library.plot_tools import plot
from library.utils import file_utils
from library.tf.models.cnn_classifier import CNNClassifier

# %% [markdown]
# ## Select Tensorflow device

# %%
# from tensorflow.python.client import device_lib
# local_device_protos = device_lib.list_local_devices()
# cpu_devices = [x.name for x in local_device_protos if x.device_type == 'CPU']
# gpu_devices = [x.name for x in local_device_protos if x.device_type == 'GPU']
# print('Available CPU Devices: ', end='')
# print(cpu_devices)
# print('Available GPU Devices: ', end='')
# print(gpu_devices)
# if len(gpu_devices) == 0:
#     if len(cpu_devices) > 0:
#         device_name = '/cpu:0'
#         print('Using CPU: %s' %device_name)
#     else:
#         print('No CPU present in the system!!!')
# else:
#     device_name = '/gpu:0'
#     print('Using GPU: %s' %device_name)

# %%
total_time = 0

# %% [markdown]
# ## Experiment

# %%
exp_no = 2
data_source = 'Website'
num_images_required = 1.0
file_no = 105

# %% [markdown]
# ### Parameters for experiment

# %%
device_name = '/gpu:0'
learn_rate = 0.001
train_epochs = 50
display_step = 1
reg_const = 0.01
train_val_split_data = None
train_val_split = 0.8
transform = True
transform_method = 'StandardScaler'
learn_rate_type = 'constant'
dataset = 'cifar10'
descent_method = 'adam'
batch_size = 96
model_restore = False

# %% [markdown]
# ### Log directories

# %%
log_dir = '../logs/' + dataset + '/' + str(file_no).zfill(3) + '_tf_cnn_raw/exp_no_' + str(exp_no).zfill(3) + '/'
log_file = log_dir + 'cnn_classifier.ckpt'
model_file = log_dir + 'cnn_classifier.pb'
print('Writing tensorboard logs to %s' % log_file)
print('View logs by running tensorboard: ', end='')
print('\"tensorboard --logdir=\'./%s/105_tf_cnn_raw/\' --port 61111\"' % dataset)
# Out:
# Writing tensorboard logs to ../logs/cifar10/105_tf_cnn_raw/exp_no_002/cnn_classifier.ckpt
# View logs by running tensorboard: "tensorboard --logdir='./cifar10/105_tf_cnn_raw/' --port 61111"

# %% [markdown]
# ## Step 1: Load CIFAR 10 Dataset

# %%
start = time.time()
one_hot = True
make_image = True
cifar10 = CIFAR10(one_hot_encode=one_hot, num_images=num_images_required, preprocess='StandardScaler',
                  train_validate_split=train_val_split_data, make_image=make_image, endian='little')
cifar10.load_data(train=True, test=True, data_directory='./datasets/cifar10/')
end = time.time()
print('[ Step 1] Loaded CIFAR 10 Dataset in %.4f ms' %((end-start)*1000))
total_time += (end-start)
# Out:
# Loading CIFAR 10 Dataset
# Downloading and extracting CIFAR 10 file
# MD5sum of the file: ./datasets/cifar10/cifar-10.tar.gz is verified
# Loading 50000 train images
# Loading CIFAR 10 Training Dataset
# Reading unpicked data file: ./datasets/cifar10/cifar-10-batches/data_batch_1
# Reading unpicked data file: ./datasets/cifar10/cifar-10-batches/data_batch_2
# Reading unpicked data file: ./datasets/cifar10/cifar-10-batches/data_batch_3
# Reading unpicked data file: ./datasets/cifar10/cifar-10-batches/data_batch_4
# Reading unpicked data file: ./datasets/cifar10/cifar-10-batches/data_batch_5
# /net/voxel03/misc/me/praneethas/Softwares/anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:429: DataConversionWarning: Data with input dtype uint8 was converted to float64 by StandardScaler.
#   warnings.warn(msg, _DataConversionWarning)
# Loading 10000 test images
# Loading CIFAR 10 Test Dataset
# Unpickling test file: ./datasets/cifar10/cifar-10-batches/test_batch
# Reading unpicked test file: ./datasets/cifar10/cifar-10-batches/test_batch
# Loaded CIFAR 10 Dataset in 5.5624 seconds
# [ Step 1] Loaded CIFAR 10 Dataset in 5563.0589 ms

# %%
# print('Train data shape:', cifar10.train.data.shape)
# if one_hot is True:
#     print('Train labels shape:', cifar10.train.one_hot_labels.shape)
# print('Train class labels shape:', cifar10.train.class_labels.shape)
# if train_val_split_data is not None:
#     print('Validate data shape:', cifar10.validate.data.shape)
#     if one_hot is True:
#         print('Validate labels shape:', cifar10.validate.one_hot_labels.shape)
#     print('Validate class labels shape:', cifar10.validate.class_labels.shape)
# print('Test data shape:', cifar10.test.data.shape)
# if one_hot is True:
#     print('Test labels shape:', cifar10.test.one_hot_labels.shape)
# print('Test class labels shape:', cifar10.test.class_labels.shape)

# %%
# print('Training images')
# print(cifar10.train.data[:5])
# if one_hot is True:
#     print('Training labels')
#     print(cifar10.train.one_hot_labels[:5])
# print('Training classes')
# print(cifar10.train.class_labels[:5])
# print('Testing images')
# print(cifar10.test.data[:5])
# if one_hot is True:
#     print('Testing labels')
#     print(cifar10.test.one_hot_labels[:5])
# print('Testing classes')
# print(cifar10.test.class_labels[:5])

# %% [markdown]
# ## Step 1.1 Load sample images

# %%
cifar10.plot_sample(plot_data=True, plot_test=True, fig_size=(7, 7))
# Out:
# Plotting CIFAR 10 Train Dataset
# Plotting CIFAR 10 Test Dataset

# %%
cifar10.plot_images(cifar10.train.data[:50, :], cifar10.train.class_names[:50], 
                    nrows=5, ncols=10, fig_size=(20,50), fontsize=35, convert=True)
# Out:
# True

# %% [markdown]
# ## Step 2: Convolution Neural Network

# %%
image_shape = cifar10.train.images[1,:].shape
num_classes = 10

# %%
network_config = {'conv_layer_1': {'weight': {'name': 'Weight_conv_layer_1', 'type': 'random_normal'},
                                          'bias': {'name': 'Bias_conv_layer_1', 'type': 'zeros'},
                                          'activation_fn': 'relu',
                                          'stride': 1, 'padding': 'SAME',
                                          'filter_size': 3, 'num_outputs': 32,
                                          'layer_name': 'Convolution_Layer_1'
                                  },
                 'max_pool_layer_1': {'stride': 2, 'overlap': 2, 'padding': 'SAME',
                                      'layer_name': 'MaxPool_Layer_1'
                                     },
                  'conv_layer_2': {'weight': {'name': 'Weight_conv_layer_2', 'type': 'random_normal'},
                                          'bias': {'name': 'Bias_conv_layer_2', 'type': 'zeros'},
                                          'activation_fn': 'relu',
                                          'stride': 1, 'padding': 'SAME',
                                          'filter_size': 3, 'num_outputs': 128,
                                          'layer_name': 'Convolution_Layer_2'
                                  },
                  'max_pool_layer_2': {'stride': 2, 'overlap': 2, 'padding': 'SAME',
                                      'layer_name': 'MaxPool_Layer_2'
                                     },
                  'conv_layer_3': {'weight': {'name': 'Weight_conv_layer_3', 'type': 'random_normal'},
                                          'bias': {'name': 'Bias_conv_layer_3', 'type': 'zeros'},
                                          'activation_fn': 'relu',
                                          'stride': 1, 'padding': 'SAME',
                                          'filter_size': 3, 'num_outputs': 512,
                                          'layer_name': 'Convolution_Layer_3'
                                  },
                 'max_pool_layer_3': {'stride': 2, 'overlap': 2, 'padding': 'SAME',
                                      'layer_name': 'MaxPool_Layer_3'
                                     },
                 'full_connected_layer_1': {'weight': {'name': 'Full_Weight_full_connect', 'type': 'truncated_normal'},
                                            'bias': {'name': 'Full_Bias_full_connect', 'type': 'zeros'},
                                            'activation_fn': 'relu', 'num_outputs': 1024, 'dropout': 0.5,
                                            'layer_name': 'Full_Connected_Layer'
                                           },
                  'output_layer': {'weight': {'name': 'Output_Weight_output', 'type': 'truncated_normal'},
                                   'bias': {'name': 'Output_Bias_output', 'type': 'zeros'},
                                   'activation_fn': 'relu',
                                   'layer_name': 'Output_Layer'
                                  }
                 }

# %%
augmentation = {'flip_left_right': {'seed': 1},
                'rotate': {'max_angle': 20}}
augmentation_01 = {'flip_left_right': {'seed': 1}}
augmentation_02 = {'rotate': {'max_angle': 20}}
# augmentation = None

# %%
cnn = CNNClassifier(verbose=False, device=device_name, session_type='interactive', num_iter=train_epochs, 
                    err_tolerance=1e-7, train_validate_split=train_val_split, display_step=display_step,
                    learn_step=10, learn_rate_type=learn_rate_type, learn_rate=learn_rate, batch_size=batch_size, 
                    logs=True, log_dir=log_dir, test_log=True, save_model=False, checkpoint_filename=log_file, 
                    save_checkpoint=True, restore=model_restore, model_name=model_file, 
                    descent_method=descent_method, config=network_config, augmentation=augmentation)

# %%
cnn.augmentation = augmentation_01
data, labels, classes = cnn.make_data(cifar10.train.images, cifar10.train.one_hot_labels, cifar10.train.class_labels)
prediction_classes = []
classes = np.array(classes)
for i in range(classes.shape[0]):
    prediction_classes.append(cifar10.classes[int(classes[i])])
prediction_classes = np.array(prediction_classes)
cifar10.plot_images(data[:50, :], prediction_classes[:50], nrows=5, ncols=10, fig_size=(20,50), fontsize=35, convert=False)
# Out:
# Performing augmentation
# True

# %%
cnn.augmentation = augmentation_02
data, labels, classes = cnn.make_data(cifar10.train.images, cifar10.train.one_hot_labels, cifar10.train.class_labels)
prediction_classes = []
classes = np.array(classes)
for i in range(classes.shape[0]):
    prediction_classes.append(cifar10.classes[int(classes[i])])
prediction_classes = np.array(prediction_classes)
cifar10.plot_images(data[:50, :], prediction_classes[:50], nrows=5, ncols=10, fig_size=(20,50), fontsize=35, convert=False)
# Out:
# Performing augmentation
# True

# %% [markdown]
# ### Step 2.2: Create the tensorflow graph

# %%
start = time.time()
cnn.augmentation = augmentation
cnn.create_graph(image_shape, num_classes=num_classes)
end = time.time()
print('Generated the tensorflow graph in %.4f ms' %((end-start)*1000))
total_time = (end-start)
# Out:
# None -> conv_layer_1
# Making convolution layer: conv_layer_1
# 3 3 3 32
# Input shape: [None, 32, 32, 3]
# Weight_conv_layer_1
# Output shape: [None, 32, 32, 32]
# conv_layer_1 -> max_pool_layer_1
# Making max pool layer: max_pool_layer_1
# Input shape: [None, 32, 32, 32]
# Output shape: [None, 16, 16, 32]
# max_pool_layer_1 -> conv_layer_2
# Making convolution layer: conv_layer_2
# 3 3 32 128
# Input shape: [None, 16, 16, 32]
# Weight_conv_layer_2
# Output shape: [None, 16, 16, 128]
# conv_layer_2 -> max_pool_layer_2
# Making max pool layer: max_pool_layer_2
# Input shape: [None, 16, 16, 128]
# Output shape: [None, 8, 8, 128]
# max_pool_layer_2 -> conv_layer_3
# Making convolution layer: conv_layer_3
# 3 3 128 512
# Input shape: [None, 8, 8, 128]
# Weight_conv_layer_3
# Output shape: [None, 8, 8, 512]
# conv_layer_3 -> max_pool_layer_3
# Making max pool layer: max_pool_layer_3
# Input shape: [None, 8, 8, 512]
# Output shape: [None, 4, 4, 512]
# max_pool_layer_3 -> full_connected_layer_1
# Making full connected layer: full_connected_layer_1
# Input shape: [None, 8192]
# Output shape: [None, 1024]
# full_connected_layer_1 -> output_layer
# Making output layer: output_layer
# Input shape: [None, 1024]
# Output shape: [None, 10]
# Made cross entropy
# ['last_successful_epoch/initial_value', 'last_successful_epoch', 'last_successful_epoch/Assign', 'last_successful_epoch/read', 'add/y', 'add', 'assign_updated_epoch', 'Inputs/Data/X_input', 'Inputs/Train_Labels/y_true_one_hot_label', 'Inputs/Train_Labels/y_true_class', 'Layers/conv_layer_1/random_normal/shape', 'Layers/conv_layer_1/random_normal/mean', 'Layers/conv_layer_1/random_normal/stddev', 'Layers/conv_layer_1/random_normal/RandomStandardNormal', 'Layers/conv_layer_1/random_normal/mul', 'Layers/conv_layer_1/random_normal', 'Layers/conv_layer_1/Weight_conv_layer_1', 'Layers/conv_layer_1/Weight_conv_layer_1/Assign', 'Layers/conv_layer_1/Weight_conv_layer_1/read', 'Layers/conv_layer_1/zeros', 'Layers/conv_layer_1/Bias_conv_layer_1', 'Layers/conv_layer_1/Bias_conv_layer_1/Assign', 'Layers/conv_layer_1/Bias_conv_layer_1/read', 'Layers/conv_layer_1/Conv2D', 'Layers/conv_layer_1/BiasAdd', 'Layers/conv_layer_1/conv_layer_1', 'Layers/max_pool_layer_1/max_pool_layer_1', 'Layers/conv_layer_2/random_normal/shape', 'Layers/conv_layer_2/random_normal/mean', 'Layers/conv_layer_2/random_normal/stddev', 'Layers/conv_layer_2/random_normal/RandomStandardNormal', 'Layers/conv_layer_2/random_normal/mul', 'Layers/conv_layer_2/random_normal', 'Layers/conv_layer_2/Weight_conv_layer_2', 'Layers/conv_layer_2/Weight_conv_layer_2/Assign', 'Layers/conv_layer_2/Weight_conv_layer_2/read', 'Layers/conv_layer_2/zeros', 'Layers/conv_layer_2/Bias_conv_layer_2', 'Layers/conv_layer_2/Bias_conv_layer_2/Assign', 'Layers/conv_layer_2/Bias_conv_layer_2/read', 'Layers/conv_layer_2/Conv2D', 'Layers/conv_layer_2/BiasAdd', 'Layers/conv_layer_2/conv_layer_2', 'Layers/max_pool_layer_2/max_pool_layer_2', 'Layers/conv_layer_3/random_normal/shape', 'Layers/conv_layer_3/random_normal/mean', 'Layers/conv_layer_3/random_normal/stddev', 'Layers/conv_layer_3/random_normal/RandomStandardNormal', 'Layers/conv_layer_3/random_normal/mul', 'Layers/conv_layer_3/random_normal', 'Layers/conv_layer_3/Weight_conv_layer_3', 'Layers/conv_layer_3/Weight_conv_layer_3/Assign', 'Layers/conv_layer_3/Weight_conv_layer_3/read', 'Layers/conv_layer_3/zeros', 'Layers/conv_layer_3/Bias_conv_layer_3', 'Layers/conv_layer_3/Bias_conv_layer_3/Assign', 'Layers/conv_layer_3/Bias_conv_layer_3/read', 'Layers/conv_layer_3/Conv2D', 'Layers/conv_layer_3/BiasAdd', 'Layers/conv_layer_3/conv_layer_3', 'Layers/max_pool_layer_3/max_pool_layer_3', 'Layers/Reshape/shape', 'Layers/Reshape', 'Layers/full_connected_layer_1/truncated_normal/shape', 'Layers/full_connected_layer_1/truncated_normal/mean', 'Layers/full_connected_layer_1/truncated_normal/stddev', 'Layers/full_connected_layer_1/truncated_normal/TruncatedNormal', 'Layers/full_connected_layer_1/truncated_normal/mul', 'Layers/full_connected_layer_1/truncated_normal', 'Layers/full_connected_layer_1/Full_Weight_full_connect', 'Layers/full_connected_layer_1/Full_Weight_full_connect/Assign', 'Layers/full_connected_layer_1/Full_Weight_full_connect/read', 'Layers/full_connected_layer_1/zeros', 'Layers/full_connected_layer_1/Full_Bias_full_connect', 'Layers/full_connected_layer_1/Full_Bias_full_connect/Assign', 'Layers/full_connected_layer_1/Full_Bias_full_connect/read', 'Layers/full_connected_layer_1/full_connected_layer_1/MatMul', 'Layers/full_connected_layer_1/full_connected_layer_1', 'Layers/full_connected_layer_1/full_connected_layer_1_1', 'Layers/output_layer/truncated_normal/shape', 'Layers/output_layer/truncated_normal/mean', 'Layers/output_layer/truncated_normal/stddev', 'Layers/output_layer/truncated_normal/TruncatedNormal', 'Layers/output_layer/truncated_normal/mul', 'Layers/output_layer/truncated_normal', 'Layers/output_layer/Output_Weight_output', 'Layers/output_layer/Output_Weight_output/Assign', 'Layers/output_layer/Output_Weight_output/read', 'Layers/output_layer/zeros', 'Layers/output_layer/Output_Bias_output', 'Layers/output_layer/Output_Bias_output/Assign', 'Layers/output_layer/Output_Bias_output/read', 'Layers/output_layer/output_layer/MatMul', 'La ...
# Session: <tensorflow.python.client.session.InteractiveSession object at 0x7f7dcb76f240>
# Model has been trained for 0 iterations
# Tensorflow graph created in 1.6855 seconds
# Generated the tensorflow graph in 1685.9505 ms

# %%
cnn.print_parameters()
# Out:
# Parameters for CNN classifier
# >> Input Parameters
# Input                  : Tensor("Inputs/Data/X_input:0", shape=(?, 32, 32, 3), dtype=float32, device=/device:GPU:0)
# True one hot labels    : Tensor("Inputs/Train_Labels/y_true_one_hot_label:0", shape=(?, 10), dtype=float32, device=/device:GPU:0)
# True class             : Tensor("Inputs/Train_Labels/y_true_class:0", shape=(?,), dtype=int64, device=/device:GPU:0)
# Predict one hot labels : Tensor("Predictions/one_hot:0", shape=(?, 10), dtype=float32, device=/device:GPU:0)
# Predict class          : Tensor("Predictions/predict_class:0", shape=(?,), dtype=int64, device=/device:GPU:0)
# Output Logits  : Tensor("Predictions/Softmax:0", shape=(?, 10), dtype=float32, device=/device:GPU:0)
# Entropy        : Tensor("Cross_Entropy/Reshape_2:0", shape=(?,), dtype=float32, device=/device:GPU:0)
# Predictions    : Tensor("Equal:0", shape=(?,), dtype=bool, device=/device:GPU:0)
# Optimizer      : name: "Optimizer/Adam"
# op: "NoOp"
# input: "^Optimizer/Adam/update_Layers/conv_layer_1/Weight_conv_layer_1/ApplyAdam"
# input: "^Optimizer/Adam/update_Layers/conv_layer_1/Bias_conv_layer_1/ApplyAdam"
# input: "^Optimizer/Adam/update_Layers/conv_layer_2/Weight_conv_layer_2/ApplyAdam"
# input: "^Optimizer/Adam/update_Layers/conv_layer_2/Bias_conv_layer_2/ApplyAdam"
# input: "^Optimizer/Adam/update_Layers/conv_layer_3/Weight_conv_layer_3/ApplyAdam"
# input: "^Optimizer/Adam/update_Layers/conv_layer_3/Bias_conv_layer_3/ApplyAdam"
# input: "^Optimizer/Adam/update_Layers/full_connected_layer_1/Full_Weight_full_connect/ApplyAdam"
# input: "^Optimizer/Adam/update_Layers/full_connected_layer_1/Full_Bias_full_connect/ApplyAdam"
# input: "^Optimizer/Adam/update_Layers/output_layer/Output_Weight_output/ApplyAdam"
# input: "^Optimizer/Adam/update_Layers/output_layer/Output_Bias_output/ApplyAdam"
# input: "^Optimizer/Adam/Assign"
# input: "^Optimizer/Adam/Assign_1"
# device: "/device:GPU:0"
#
# >> Model params
# last_successful_epoch/initial_value
# last_successful_epoch
# last_successful_epoch/Assign
# last_successful_epoch/read
# add/y
# add
# assign_updated_epoch
# Inputs/Data/X_input
# Inputs/Train_Labels/y_true_one_hot_label
# Inputs/Train_Labels/y_true_class
# Layers/conv_layer_1/random_normal/shape
# Layers/conv_layer_1/random_normal/mean
# Layers/conv_layer_1/random_normal/stddev
# Layers/conv_layer_1/random_normal/RandomStandardNormal
# Layers/conv_layer_1/random_normal/mul
# Layers/conv_layer_1/random_normal
# Layers/conv_layer_1/Weight_conv_layer_1
# Layers/conv_layer_1/Weight_conv_layer_1/Assign
# Layers/conv_layer_1/Weight_conv_layer_1/read
# Layers/conv_layer_1/zeros
# Layers/conv_layer_1/Bias_conv_layer_1
# Layers/conv_layer_1/Bias_conv_layer_1/Assign
# Layers/conv_layer_1/Bias_conv_layer_1/read
# Layers/conv_layer_1/Conv2D
# Layers/conv_layer_1/BiasAdd
# Layers/conv_layer_1/conv_layer_1
# Layers/max_pool_layer_1/max_pool_layer_1
# Layers/conv_layer_2/random_normal/shape
# Layers/conv_layer_2/random_normal/mean
# Layers/conv_layer_2/random_normal/stddev
# Layers/conv_layer_2/random_normal/RandomStandardNormal
# Layers/conv_layer_2/random_normal/mul
# Layers/conv_layer_2/random_normal
# Layers/conv_layer_2/Weight_conv_layer_2
# Layers/conv_layer_2/Weight_conv_layer_2/Assign
# Layers/conv_layer_2/Weight_conv_layer_2/read
# Layers/conv_layer_2/zeros
# Layers/conv_layer_2/Bias_conv_layer_2
# Layers/conv_layer_2/Bias_conv_layer_2/Assign
# Layers/conv_layer_2/Bias_conv_layer_2/read
# Layers/conv_layer_2/Conv2D
# Layers/conv_layer_2/BiasAdd
# Layers/conv_layer_2/conv_layer_2
# Layers/max_pool_layer_2/max_pool_layer_2
# Layers/conv_layer_3/random_normal/shape
# Layers/conv_layer_3/random_normal/mean
# Layers/conv_layer_3/random_normal/stddev
# Layers/conv_layer_3/random_normal/RandomStandardNormal
# Layers/conv_layer_3/random_normal/mul
# Layers/conv_layer_3/random_normal
# Layers/conv_layer_3/Weight_conv_layer_3
# Layers/conv_layer_3/Weight_conv_layer_3/Assign
# Layers/conv_layer_3/Weight_conv_layer_3/read
# Layers/conv_layer_3/zeros
# Layers/conv_layer_3/Bias_conv_layer_3
# Layers/conv_layer_3/Bias_conv_layer_3/Assign
# Layers/conv_layer_3/Bias_conv_layer_3/read
# Layers/conv_layer_3/Conv2D
# Layers/conv_layer_3/BiasAdd
# Layers/conv_layer_3/conv_layer_3
# Layers/max_pool_layer_3/max_pool_layer_3
# Layers/Reshape/shape
# Layers/Reshape
# Layers/full_connected_layer_1/truncated_normal/shape
# Layers/full_connected_layer_1/truncated_normal/mean
# Layers/full_connected_layer_1/truncated_normal/stddev
# Layers/full_connected_layer_1/truncated_normal/TruncatedNormal
# Layers/full_connected_layer_1/truncated_normal/mul
# Layers/full_connected_layer_1/truncated_normal
# Layers/full_connected_layer_1/Full_Weight_full_connect
# Layers/full_connected_layer_1/Full_Weight_full_connect/Assign
# Layers/full_connected_layer_1/Full_Weight_full_connect/read
# Layers/full_connected_layer_1/zeros
# Layers/full_connected_layer_1/Full_Bias_full_connect
# Layers/full_connected_layer_1/Full_Bias_full_connect/Assign
# Layers/full_connected_layer_1/Full_Bias_full_connect/read
# Layers/full_connected_layer_1/full_connected_layer_1/MatMul
# Layers/full_connected_layer_1/full_connected_layer_1
# Layers/full_connected_layer_1/full_connected_layer_1_1
# Layers/output_layer/truncated_normal/shape
# Layers/output_layer/truncated_normal/mean
# Layers/output_layer/truncated_normal/stddev
# Layers/output_layer/truncated_normal/TruncatedNormal
# Layers/output_layer/truncated_normal/mul
# Layers/output_layer/truncated_normal
# Layers/output_layer/Output_Weight_output
# Layers/output_layer/Output_Weight_output/Assign
# Layers/output_layer/Output_Weight_output/read
# Layers/output_layer/zeros
# Layers/output_layer/Output_Bias_output
# Layers/output_layer/Output_Bias_output/Assign
# Layers/output_layer/Output_Bias_output/read
# Layers/output_layer/output_layer/MatMul
# Layers/output_layer/output_layer
# Layers/output_layer/output_layer_1
# Predictions/Softmax
# Predictions/predict_class/dimension
# Predictions/predict_class
# Predictions/one_hot/Const
# Predictions/one_hot/Const_1
# Predictions/one_hot/depth
# Predictions/one_hot/on_value
# Predictions/one_hot/off_value
# Predictions/one_hot
# Cross_Entropy/Rank
# Cross_Entropy/Shape
# Cross_Entropy/Rank_1
# Cross_Entropy/Shape_1
# Cross_Entropy/Sub/y
# Cross_Entropy/Sub
# Cross_Entropy/Slice/begin
# Cross_Entropy/Slice/size
# Cross_Entropy/Slice
# Cross_Entropy/concat/values_0
# Cross_Entropy/concat/axis
# Cross_Entropy/concat
# Cross_Entropy/Reshape
# Cross_Entropy/Rank_2
# Cross_Entropy/Shape_2
# Cross_Entropy/Sub_1/y
# Cross_Entropy/Sub_1
# Cross_Entropy/Slice_1/begin
# Cross_Entropy/Slice_1/size
# Cross_Entropy/Slice_1
# Cross_Entropy/concat_1/values_0
# Cross_Entropy/concat_1/axis
# Cross_Entropy/concat_1
# Cross_Entropy/Reshape_1
# Cross_Entropy/SoftmaxCrossEntropyWithLogits
# Cross_Entropy/Sub_2/y
# Cross_Entropy/Sub_2
# Cross_Entropy/Slice_2/begin
# Cross_Entropy/Slice_2/size
# Cross_Entropy/Slice_2
# Cross_Entropy/Reshape_2
# Loss_Function/Const
# Loss_Function/Mean
# Loss_Function/train_loss_list/initial_value
# Loss_Function/train_loss_list
# Loss_Function/train_loss_list/Assign
# Loss_Function/train_loss_list/read
# Loss_Function/Assign/value
# Loss_Function/Assign
# Loss_Function/train_error/tags
# Loss_Function/train_error
# Loss_Function/validate_loss_list/initial_value
# Loss_Function/validate_loss_list
# Loss_Function/validate_loss_list/Assign
# Loss_Function/validate_loss_list/read
# Loss_Function/Assign_1/value
# Loss_Function/Assign_1
# Loss_Function/validate_error/tags
# Loss_Function/validate_error
# Optimizer/learning_rate_progress/initial_value
# Optimizer/learning_rate_progress
# Optimizer/learning_rate_progress/Assign
# Optimizer/learning_rate_progress/read
# Optimizer/Assign/value
# Optimizer/Assign
# Optimizer/learning_rate/tags
# Optimizer/learning_rate/values
# Optimizer/learning_rate
# Optimizer/gradients/Shape
# Optimizer/gradients/Const
# Optimizer/gradients/Fill
# Optimizer/gradients/Loss_Function/Mean_grad/Reshape/shape
# Optimizer/gradients/Loss_Function/Mean_grad/Reshape
# Optimizer/gradients/Loss_Function/Mean_grad/Shape
# Optimizer/gradients/Loss_Function/Mean_grad/Tile
# Optimizer/gradients/Loss_Function/Mean_grad/Shape_1
# Optimizer/gradients/Loss_Function/Mean_grad/Shape_2
# Optimizer/gradients/Loss_Function/Mean_grad/Const
# Optimizer/gradients/Loss_Function/Mean_grad/Prod
# Optimizer/gradients/Loss_Function/Mean_grad/Const_1
# Optimizer/gradients/Loss_Function/Mean_grad/Prod_1
# Optimizer/gradients/Loss_Function/Mean_grad/Maximum/y
# Optimizer/gradients/Loss_Function/Mean_grad/Maximum
# Optimizer/gradients/Loss_Function/Mean_grad/floordiv
# Optimizer/gradients/Loss_Function/Mean_grad/Cast
# Optimizer/gradients/Loss_Function/Mean_grad/truediv
# Optimizer/gradients/Cross_Entropy/Reshape_2_grad/Shape
# Optimizer/gradients/Cross_Entropy/Reshape_2_grad/Reshape
# Optimizer/gradients/zeros_like
# Optimizer/gradients/Cross_Entropy/SoftmaxCrossEntropyWithLogits_grad/PreventGradient
# Optimizer/gradients/Cross_Entropy/SoftmaxCrossEntropyWithLogits_grad/ExpandDims/dim
# Optimizer/gradients/Cross_Entropy/SoftmaxCrossEntropyWithLogits_grad/ExpandDims
# Optimizer/gradients/Cross_Entropy/SoftmaxCrossEntropyWithLogits_grad/mul
# Optimizer/gradients/Cross_Entropy/Reshape_grad/Shape
# Optimizer/gradients/Cross_Entropy/Reshape_grad/Reshape
# Optimizer/gradients/Layers/output_layer/output_layer_1_grad/SigmoidGrad
# Optimizer/gradients/Layers/output_layer/output_layer_grad/BiasAddGrad
# Optimizer/gradients/Layers/output_layer/output_layer_grad/tuple/group_deps
# Optimizer/gradients/Layers/output_layer/output_layer_grad/tuple/control_dependency
# Optimizer/gradients/Layers/output_layer/output_layer_grad/tuple/control_dependency_1
# Optimizer/gradients/Layers/output_layer/output_layer/MatMul_grad/MatMul
# Optimizer/gradients/Layers/output_layer/output_layer/MatMul_grad/MatMul_1
# Optimizer/gradients/Layers/output_layer/output_layer/MatMul_grad/tuple/group_deps
# Optimizer/gradients/Layers/output_layer/output_layer/MatMul_grad/tuple/control_dependency
# Optimizer/gradients/Layers/output_layer/output_layer/MatMul_grad/tuple/control_dependency_1
# Optimizer/gradients/Layers/full_connected_layer_1/full_connected_layer_1_1_grad/SigmoidGrad
# Optimizer/gradients/Layers/full_connected_layer_1/full_connected_layer_1_grad/BiasAddGrad
# Optimizer/gradients/Layers/full_connected_layer_1/full_connected_layer_1_grad/tuple/group_deps
# Optimizer/gradients/Layers/full_connected_layer_1/full_connected_layer_1_grad/tuple/control_dependency
# Optimizer/gradients/Layers/full_connected_layer_1/full_connected_layer_1_grad/tuple/control_dependency_1
# Optimizer/gradients/Layers/full_connected_layer_1/full_connected_layer_1/MatMul_grad/MatMul
# Optimizer/gradients/Layers/full_connected_layer_1/full_connected_layer_1/MatMul_grad/MatMul_1
# Optimizer/gradients/Layers/full_connected_layer_1/full_connected_layer_1/MatMul_grad/tuple/group_deps
# Optimizer/gradients/Layers/full_connected_layer_1/full_connected_layer_1/MatMul_grad/tuple/control_dependency
# Optimizer/gradients/Layers/full_connected_layer_1/full_connected_layer_1/MatMul_grad/tuple/control_dependency_1
# Optimizer/gradients/Layers/Reshape_grad/Shape
# Optimizer/gradients/Layers/Reshape_grad/Reshape
# Optimizer/gradients/Layers/max_pool_layer_3/max_pool_layer_3_grad/MaxPoolGrad
# Optimizer/gradients/Layers/conv_layer_3/conv_layer_3_grad/ReluGrad
# Optimizer/gradients/Layers/conv_layer_3/BiasAdd_grad/BiasAddGrad
# Optimizer/gradients/Layers/conv_layer_3/BiasAdd_grad/tuple/group_deps
# Optimizer/gradients/Layers/conv_layer_3/BiasAdd_grad/tuple/control_dependency
# Optimizer/gradients/Layers/conv_layer_3/BiasAdd_grad/tuple/control_dependency_1
# Optimizer/gradients/Layers/conv_layer_3/Conv2D_grad/Shape
# Optimizer/gradients/Layers/conv_layer_3/Conv2D_grad/Conv2DBackpropInput
# Optimizer/gradients/Layers/conv_layer_3/Conv2D_grad/Shape_1
# Optimizer/gradients/Layers/conv_layer_3/Conv2D_grad/Conv2DBackpropFilter
# Optimizer/gradients/Layers/conv_layer_3/Conv2D_grad/tuple/group_deps
# Optimizer/gradients/Layers/conv_layer_3/Conv2D_grad/tuple/control_dependency
# Optimizer/gradients/Layers/conv_layer_3/Conv2D_grad/tuple/control_dependency_1
# Optimizer/gradients/Layers/max_pool_layer_2/max_pool_layer_2_grad/MaxPoolGrad
# Optimizer/gradients/Layers/conv_layer_2/conv_layer_2_grad/ReluGrad
# Optimizer/gradients/Layers/conv_layer_2/BiasAdd_grad/BiasAddGrad
# Optimizer/gradients/Layers/conv_layer_2/BiasAdd_grad/tuple/group_deps
# Optimizer/gradients/Layers/conv_layer_2/BiasAdd_grad/tuple/control_dependency
# Optimizer/gradients/Layers/conv_layer_2/BiasAdd_grad/tuple/control_dependency_1
# Optimizer/gradients/Layers/conv_layer_2/Conv2D_grad/Shape
# Optimizer/gradients/Layers/conv_layer_2/Conv2D_grad/Conv2DBackpropInput
# Optimizer/gradients/Layers/conv_layer_2/Conv2D_grad/Shape_1
# Optimizer/gradients/Layers/conv_layer_2/Conv2D_grad/Conv2DBackpropFilter
# Optimizer/gradients/Layers/conv_layer_2/Conv2D_grad/tuple/group_deps
# Optimizer/gradients/Layers/conv_layer_2/Conv2D_grad/tuple/control_dependency
# Optimizer/gradients/Layers/conv_layer_2/Conv2D_grad/tuple/control_dependency_1
# Optimizer/gradients/Layers/max_pool_layer_1/max_pool_layer_1_grad/MaxPoolGrad
# Optimizer/gradients/Layers/conv_layer_1/conv_layer_1_grad/ReluGrad
# Optimizer/gradients/Layers/conv_layer_1/BiasAdd_grad/BiasAddGrad
# Optimizer/gradients/Layers/conv_layer_1/BiasAdd_grad/tuple/group_deps
# Optimizer/gradients/Layers/conv_layer_1/BiasAdd_grad/tuple/control_dependency
# Optimizer/gradients/Layers/conv_layer_1/BiasAdd_grad/tuple/control_dependency_1
# Optimizer/gradients/Layers/conv_layer_1/Conv2D_grad/Shape
# Optimizer/gradients/Layers/conv_layer_1/Conv2D_grad/Conv2DBackpropInput
# Optimizer/gradients/Layers/conv_layer_1/Conv2D_grad/Shape_1
# Optimizer/gradients/Layers/conv_layer_1/Conv2D_grad/Conv2DBackpropFilter
# Optimizer/gradients/Layers/conv_layer_1/Conv2D_grad/tuple/group_deps
# Optimizer/gradients/Layers/conv_layer_1/Conv2D_grad/tuple/control_dependency
# Optimizer/gradients/Layers/conv_layer_1/Conv2D_grad/tuple/control_dependency_1
# Optimizer/beta1_power/initial_value
# Optimizer/beta1_power
# Optimizer/beta1_power/Assign
# Optimizer/beta1_power/read
# Optimizer/beta2_power/initial_value
# Optimizer/beta2_power
# Optimizer/beta2_power/Assign
# Optimizer/beta2_power/read
# Optimizer/zeros
# Layers/conv_layer_1/Weight_conv_layer_1/Adam
# Layers/conv_layer_1/Weight_conv_layer_1/Adam/Assign
# Layers/conv_layer_1/Weight_conv_layer_1/Adam/read
# Optimizer/zeros_1
# Layers/conv_layer_1/Weight_conv_layer_1/Adam_1
# Layers/conv_layer_1/Weight_conv_layer_1/Adam_1/Assign
# Layers/conv_layer_1/Weight_conv_layer_1/Adam_1/read
# Optimizer/zeros_2
# Layers/conv_layer_1/Bias_conv_layer_1/Adam
# Layers/conv_layer_1/Bias_conv_layer_1/Adam/Assign
# Layers/conv_layer_1/Bias_conv_layer_1/Adam/read
# Optimizer/zeros_3
# Layers/conv_layer_1/Bias_conv_layer_1/Adam_1
# Layers/conv_layer_1/Bias_conv_layer_1/Adam_1/Assign
# Layers/conv_layer_1/Bias_conv_layer_1/Adam_1/read
# Optimizer/zeros_4
# Layers/conv_layer_2/Weight_conv_layer_2/Adam
# Layers/conv_layer_2/Weight_conv_layer_2/Adam/Assign
# Layers/conv_layer_2/Weight_conv_layer_2/Adam/read
# Optimizer/zeros_5
# Layers/conv_layer_2/Weight_conv_layer_2/Adam_1
# Layers/conv_layer_2/Weight_conv_layer_2/Adam_1/Assign
# Layers/conv_layer_2/Weight_conv_layer_2/Adam_1/read
# Optimizer/zeros_6
# Layers/conv_layer_2/Bias_conv_layer_2/Adam
# Layers/conv_layer_2/Bias_conv_layer_2/Adam/Assign
# Layers/conv_layer_2/Bias_conv_layer_2/Adam/read
# Optimizer/zeros_7
# Layers/conv_layer_2/Bias_conv_layer_2/Adam_1
# Layers/conv_layer_2/Bias_conv_layer_2/Adam_1/Assign
# Layers/conv_layer_2/Bias_conv_layer_2/Adam_1/read
# Optimizer/zeros_8
# Layers/conv_layer_3/Weight_conv_layer_3/Adam
# Layers/conv_layer_3/Weight_conv_layer_3/Adam/Assign
# Layers/conv_layer_3/Weight_conv_layer_3/Adam/read
# Optimizer/zeros_9
# Layers/conv_layer_3/Weight_conv_layer_3/Adam_1
# Layers/conv_layer_3/Weight_conv_layer_3/Adam_1/Assign
# Layers/conv_layer_3/Weight_conv_layer_3/Adam_1/read
# Optimizer/zeros_10
# Layers/conv_layer_3/Bias_conv_layer_3/Adam
# Layers/conv_layer_3/Bias_conv_layer_3/Adam/Assign
# Layers/conv_layer_3/Bias_conv_layer_3/Adam/read
# Optimizer/zeros_11
# Layers/conv_layer_3/Bias_conv_layer_3/Adam_1
# Layers/conv_layer_3/Bias_conv_layer_3/Adam_1/Assign
# Layers/conv_layer_3/Bias_conv_layer_3/Adam_1/read
# Optimizer/zeros_12
# Layers/full_connected_layer_1/Full_Weight_full_connect/Adam
# Layers/full_connected_layer_1/Full_Weight_full_connect/Adam/Assign
# Layers/full_connected_layer_1/Full_Weight_full_connect/Adam/read
# Optimizer/zeros_13
# Layers/full_connected_layer_1/Full_Weight_full_connect/Adam_1
# Layers/full_connected_layer_1/Full_Weight_full_connect/Adam_1/Assign
# Layers/full_connected_layer_1/Full_Weight_full_connect/Adam_1/read
# Optimizer/zeros_14
# Layers/full_connected_layer_1/Full_Bias_full_connect/Adam
# Layers/full_connected_layer_1/Full_Bias_full_connect/Adam/Assign
# Layers/full_connected_layer_1/Full_Bias_full_connect/Adam/read
# Optimizer/zeros_15
# Layers/full_connected_layer_1/Full_Bias_full_connect/Adam_1
# Layers/full_connected_layer_1/Full_Bias_full_connect/Adam_1/Assign
# Layers/full_connected_layer_1/Full_Bias_full_connect/Adam_1/read
# Optimizer/zeros_16
# Layers/output_layer/Output_Weight_output/Adam
# Layers/output_layer/Output_Weight_output/Adam/Assign
# Layers/output_layer/Output_Weight_output/Adam/read
# Optimizer/zeros_17
# Layers/output_layer/Output_Weight_output/Adam_1
# Layers/output_layer/Output_Weight_output/Adam_1/Assign
# Layers/output_layer/Output_Weight_output/Adam_1/read
# Optimizer/zeros_18
# Layers/output_layer/Output_Bias_output/Adam
# Layers/output_layer/Output_Bias_output/Adam/Assign
# Layers/output_layer/Output_Bias_output/Adam/read
# Optimizer/zeros_19
# Layers/output_layer/Output_Bias_output/Adam_1
# Layers/output_layer/Output_Bias_output/Adam_1/Assign
# Layers/output_layer/Output_Bias_output/Adam_1/read
# Optimizer/Adam/learning_rate
# Optimizer/Adam/beta1
# Optimizer/Adam/beta2
# Optimizer/Adam/epsilon
# Optimizer/Adam/update_Layers/conv_layer_1/Weight_conv_layer_1/ApplyAdam
# Optimizer/Adam/update_Layers/conv_layer_1/Bias_conv_layer_1/ApplyAdam
# Optimizer/Adam/update_Layers/conv_layer_2/Weight_conv_layer_2/ApplyAdam
# Optimizer/Adam/update_Layers/conv_layer_2/Bias_conv_layer_2/ApplyAdam
# Optimizer/Adam/update_Layers/conv_layer_3/Weight_conv_layer_3/ApplyAdam
# Optimizer/Adam/update_Layers/conv_layer_3/Bias_conv_layer_3/ApplyAdam
# Optimizer/Adam/update_Layers/full_connected_layer_1/Full_Weight_full_connect/ApplyAdam
# Optimizer/Adam/update_Layers/full_connected_layer_1/Full_Bias_full_connect/ApplyAdam
# Optimizer/Adam/update_Layers/output_layer/Output_Weight_output/ApplyAdam
# Optimizer/Adam/update_Layers/output_layer/Output_Bias_output/ApplyAdam
# Optimizer/Adam/mul
# Optimizer/Adam/Assign
# Optimizer/Adam/mul_1
# Optimizer/Adam/Assign_1
# Optimizer/Adam
# Equal
# Accuracy/Cast
# Accuracy/Const
# Accuracy/Mean
# Accuracy/train_accuracy_list/initial_value
# Accuracy/train_accuracy_list
# Accuracy/train_accuracy_list/Assign
# Accuracy/train_accuracy_list/read
# Accuracy/Assign/value
# Accuracy/Assign
# Accuracy/train_accuracy/tags
# Accuracy/train_accuracy
# Accuracy/Cast_1
# Accuracy/Const_1
# Accuracy/Mean_1
# Accuracy/validate_accuracy_list/initial_value
# Accuracy/validate_accuracy_list
# Accuracy/validate_accuracy_list/Assign
# Accuracy/validate_accuracy_list/read
# Accuracy/Assign_1/value
# Accuracy/Assign_1
# Accuracy/validate_accuracy/tags
# Accuracy/validate_accuracy
# Accuracy/Cast_2
# Accuracy/Const_2
# Accuracy/Mean_2
# Accuracy/test_accuracy_list/initial_value
# Accuracy/test_accuracy_list
# Accuracy/test_accuracy_list/Assign
# Accuracy/test_accuracy_list/read
# Accuracy/Assign_2/value
# Accuracy/Assign_2
# Accuracy/test_accuracy/tags
# Accuracy/test_accuracy
# init/NoOp
# init/NoOp_1
# init
# Merge/MergeSummary
# save/Const
# save/SaveV2/tensor_names
# save/SaveV2/shape_and_slices
# save/SaveV2
# save/control_dependency
# save/RestoreV2/tensor_names
# save/RestoreV2/shape_and_slices
# save/RestoreV2
# save/Assign
# save/RestoreV2_1/tensor_names
# save/RestoreV2_1/shape_and_slices
# save/RestoreV2_1
# save/Assign_1
# save/RestoreV2_2/tensor_names
# save/RestoreV2_2/shape_and_slices
# save/RestoreV2_2
# save/Assign_2
# save/RestoreV2_3/tensor_names
# save/RestoreV2_3/shape_and_slices
# save/RestoreV2_3
# save/Assign_3
# save/RestoreV2_4/tensor_names
# save/RestoreV2_4/shape_and_slices
# save/RestoreV2_4
# save/Assign_4
# save/RestoreV2_5/tensor_names
# save/RestoreV2_5/shape_and_slices
# save/RestoreV2_5
# save/Assign_5
# save/RestoreV2_6/tensor_names
# save/RestoreV2_6/shape_and_slices
# save/RestoreV2_6
# save/Assign_6
# save/RestoreV2_7/tensor_names
# save/RestoreV2_7/shape_and_slices
# save/RestoreV2_7
# save/Assign_7
# save/RestoreV2_8/tensor_names
# save/RestoreV2_8/shape_and_slices
# save/RestoreV2_8
# save/Assign_8
# save/RestoreV2_9/tensor_names
# save/RestoreV2_9/shape_and_slices
# save/RestoreV2_9
# save/Assign_9
# save/RestoreV2_10/tensor_names
# save/RestoreV2_10/shape_and_slices
# save/RestoreV2_10
# save/Assign_10
# save/RestoreV2_11/tensor_names
# save/RestoreV2_11/shape_and_slices
# save/RestoreV2_11
# save/Assign_11
# save/RestoreV2_12/tensor_names
# save/RestoreV2_12/shape_and_slices
# save/RestoreV2_12
# save/Assign_12
# save/RestoreV2_13/tensor_names
# save/RestoreV2_13/shape_and_slices
# save/RestoreV2_13
# save/Assign_13
# save/RestoreV2_14/tensor_names
# save/RestoreV2_14/shape_and_slices
# save/RestoreV2_14
# save/Assign_14
# save/RestoreV2_15/tensor_names
# save/RestoreV2_15/shape_and_slices
# save/RestoreV2_15
# save/Assign_15
# save/RestoreV2_16/tensor_names
# save/RestoreV2_16/shape_and_slices
# save/RestoreV2_16
# save/Assign_16
# save/RestoreV2_17/tensor_names
# save/RestoreV2_17/shape_and_slices
# save/RestoreV2_17
# save/Assign_17
# save/RestoreV2_18/tensor_names
# save/RestoreV2_18/shape_and_slices
# save/RestoreV2_18
# save/Assign_18
# save/RestoreV2_19/tensor_names
# save/RestoreV2_19/shape_and_slices
# save/RestoreV2_19
# save/Assign_19
# save/RestoreV2_20/tensor_names
# save/RestoreV2_20/shape_and_slices
# save/RestoreV2_20
# save/Assign_20
# save/RestoreV2_21/tensor_names
# save/RestoreV2_21/shape_and_slices
# save/RestoreV2_21
# save/Assign_21
# save/RestoreV2_22/tensor_names
# save/RestoreV2_22/shape_and_slices
# save/RestoreV2_22
# save/Assign_22
# save/RestoreV2_23/tensor_names
# save/RestoreV2_23/shape_and_slices
# save/RestoreV2_23
# save/Assign_23
# save/RestoreV2_24/tensor_names
# save/RestoreV2_24/shape_and_slices
# save/RestoreV2_24
# save/Assign_24
# save/RestoreV2_25/tensor_names
# save/RestoreV2_25/shape_and_slices
# save/RestoreV2_25
# save/Assign_25
# save/RestoreV2_26/tensor_names
# save/RestoreV2_26/shape_and_slices
# save/RestoreV2_26
# save/Assign_26
# save/RestoreV2_27/tensor_names
# save/RestoreV2_27/shape_and_slices
# save/RestoreV2_27
# save/Assign_27
# save/RestoreV2_28/tensor_names
# save/RestoreV2_28/shape_and_slices
# save/RestoreV2_28
# save/Assign_28
# save/RestoreV2_29/tensor_names
# save/RestoreV2_29/shape_and_slices
# save/RestoreV2_29
# save/Assign_29
# save/RestoreV2_30/tensor_names
# save/RestoreV2_30/shape_and_slices
# save/RestoreV2_30
# save/Assign_30
# save/RestoreV2_31/tensor_names
# save/RestoreV2_31/shape_and_slices
# save/RestoreV2_31
# save/Assign_31
# save/RestoreV2_32/tensor_names
# save/RestoreV2_32/shape_and_slices
# save/RestoreV2_32
# save/Assign_32
# save/RestoreV2_33/tensor_names
# save/RestoreV2_33/shape_and_slices
# save/RestoreV2_33
# save/Assign_33
# save/RestoreV2_34/tensor_names
# save/RestoreV2_34/shape_and_slices
# save/RestoreV2_34
# save/Assign_34
# save/RestoreV2_35/tensor_names
# save/RestoreV2_35/shape_and_slices
# save/RestoreV2_35
# save/Assign_35
# save/RestoreV2_36/tensor_names
# save/RestoreV2_36/shape_and_slices
# save/RestoreV2_36
# save/Assign_36
# save/RestoreV2_37/tensor_names
# save/RestoreV2_37/shape_and_slices
# save/RestoreV2_37
# save/Assign_37
# save/RestoreV2_38/tensor_names
# save/RestoreV2_38/shape_and_slices
# save/RestoreV2_38
# save/Assign_38
# save/restore_all/NoOp
# save/restore_all/NoOp_1
# save/restore_all
# >> Model info
# Train loss     : Tensor("Loss_Function/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# Train accuracy : Tensor("Accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# Val. loss      : Tensor("Loss_Function/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# Val. accuracy  : Tensor("Accuracy/Mean_1:0", shape=(), dtype=float32, device=/device:GPU:0)
# >> Summary params
# Train loss     : Tensor("Loss_Function/train_error:0", shape=(), dtype=string, device=/device:GPU:0)
# Train accuracy : Tensor("Accuracy/train_accuracy:0", shape=(), dtype=string, device=/device:GPU:0)
# Val. loss      : Tensor("Loss_Function/validate_error:0", shape=(), dtype=string, device=/device:GPU:0)
# Val. accuracy  : Tensor("Accuracy/validate_accuracy:0", shape=(), dtype=string, device=/device:GPU:0)

# %% [markdown]
# ### Step 2.3: Fit the model/training

# %%
start = time.time()
cnn.fit(cifar10.train.images, cifar10.train.one_hot_labels, cifar10.train.class_labels,
        test_data=cifar10.test.images, test_labels=cifar10.test.one_hot_labels, 
        test_classes=cifar10.test.class_labels)
end = time.time()
print(end-start)
# Out:
# Length of train loss          : 0
# Length of train accuracy      : 0
# Length of validate loss       : 0
# Length of validate accuracy   : 0
# Length of test accuracy       : 0
# Restoring training from epoch : 0
# Training using original train data using batch size of 96 and total batches of 417
# Training using augmented train data using batch size of 96 and total batches of 626
# >>> Epoch [ 0/50]
# train_loss: 1.9867 | train_acc: 0.0000 | val_loss: 1.8057 | val_acc: 0.5526 | test_acc: 0.5503 | Time: 68.0384 s
# Training using original train data using batch size of 96 and total batches of 417
# Training using augmented train data using batch size of 96 and total batches of 626
# >>> Epoch [ 1/50]
# train_loss: 1.6917 | train_acc: 0.6944 | val_loss: 1.7058 | val_acc: 0.6853 | test_acc: 0.6886 | Time: 65.3879 s
# Training using original train data using batch size of 96 and total batches of 417
# Training using augmented train data using batch size of 96 and total batches of 626
# >>> Epoch [ 2/50]
# train_loss: 1.6342 | train_acc: 0.7595 | val_loss: 1.6761 | val_acc: 0.7209 | test_acc: 0.7212 | Time: 64.1706 s
# Training using original train data using batch size of 96 and total batches of 417
# Training using augmented train data using batch size of 96 and total batches of 626
# >>> Epoch [ 3/50]
# train_loss: 1.7166 | train_acc: 0.5000 | val_loss: 1.6645 | val_acc: 0.7374 | test_acc: 0.7356 | Time: 65.6890 s
# Training using original train data using batch size of 96 and total batches of 417
# Training using augmented train data using batch size of 96 and total batches of 625
# >>> Epoch [ 4/50]
# train_loss: 1.5809 | train_acc: 0.8056 | val_loss: 1.6607 | val_acc: 0.7460 | test_acc: 0.7451 | Time: 64.5900 s
# Training using original train data using batch size of 96 and total batches of 417
# Training using augmented train data using batch size of 96 and total batches of 626
# >>> Epoch [ 5/50]
# train_loss: 1.5804 | train_acc: 0.8267 | val_loss: 1.6446 | val_acc: 0.7720 | test_acc: 0.7691 | Time: 65.6171 s
# Training using original train data using batch size of 96 and total batches of 417
# Training using augmented train data using batch size of 96 and total batches of 625
# >>> Epoch [ 6/50]
# train_loss: 1.5590 | train_acc: 0.8929 | val_loss: 1.6393 | val_acc: 0.7811 | test_acc: 0.7781 | Time: 64.2065 s
# Training using original train data using batch size of 96 and total batches of 417
# Training using augmented train data using batch size of 96 and total batches of 626
# >>> Epoch [ 7/50]
# train_loss: 1.5441 | train_acc: 0.8837 | val_loss: 1.6443 | val_acc: 0.7809 | test_acc: 0.7790 | Time: 66.3969 s
# Training using original train data using batch size of 96 and total batches of 417
# Training using augmented train data using batch size of 96 and total batches of 624
# >>> Epoch [ 8/50]
# train_loss: 1.5566 | train_acc: 0.8810 | val_loss: 1.6447 | val_acc: 0.7798 | test_acc: 0.7802 | Time: 64.0761 s
# Training using original train data using batch size of 96 and total batches of 417
# Training using augmented train data using batch size of 96 and total batches of 625
# >>> Epoch [ 9/50]
# train_loss: 1.5780 | train_acc: 0.9111 | val_loss: 1.6413 | val_acc: 0.7871 | test_acc: 0.7822 | Time: 65.4842 s
# Training using original train data using batch size of 96 and total batches of 417
# Training using augmented train data using batch size of 96 and total batches of 626
# >>> Epoch [10/50]
# train_loss: 1.6105 | train_acc: 0.7647 | val_loss: 1.6467 | val_acc: 0.7880 | test_acc: 0.7836 | Time: 64.5486 s
# Training using original train data using batch size of 96 and total batches of 417
# Training using augmented train data using batch size of 96 and total batches of 626
# >>> Epoch [11/50]
# train_loss: 1.5983 | train_acc: 0.8400 | val_loss: 1.6376 | val_acc: 0.7972 | test_acc: 0.7917 | Time: 65.7363 s
# Training using original train data using batch size of 96 and total batches of 417
# Training using augmented train data using batch size of 96 and total batches of 624
# >>> Epoch [12/50]
# train_loss: 1.5504 | train_acc: 0.9057 | val_loss: 1.6398 | val_acc: 0.7969 | test_acc: 0.7915 | Time: 64.2370 s
# Training using original train data using batch size of 96 and total batches of 417
# Training using augmented train data using batch size of 96 and total batches of 624
# >>> Epoch [13/50]
# train_loss: 1.5318 | train_acc: 0.9286 | val_loss: 1.6424 | val_acc: 0.8000 | test_acc: 0.7939 | Time: 65.3295 s
# Training using original train data using batch size of 96 and total batches of 417
# Training using augmented train data using batch size of 96 and total batches of 626
# >>> Epoch [14/50]
# train_loss: 1.5340 | train_acc: 0.8929 | val_loss: 1.6392 | val_acc: 0.7994 | test_acc: 0.7941 | Time: 64.8638 s
# Training using original train data using batch size of 96 and total batches of 417
# Training using augmented train data using batch size of 96 and total batches of 628
# >>> Epoch [15/50]
# train_loss: 1.4889 | train_acc: 1.0000 | val_loss: 1.6376 | val_acc: 0.8014 | test_acc: 0.7974 | Time: 65.8075 s
# Training using original train data using batch size of 96 and total batches of 417
# Training using augmented train data using batch size of 96 and total batches of 625
# >>> Epoch [16/50]
# train_loss: 1.5399 | train_acc: 0.8987 | val_loss: 1.6346 | val_acc: 0.8009 | test_acc: 0.7956 | Time: 64.6431 s
# Training using original train data using batch size of 96 and total batches of 417
# Training using augmented train data using batch size of 96 and total batches of 627
# >>> Epoch [17/50]
# train_loss: 1.5253 | train_acc: 0.9535 | val_loss: 1.6317 | val_acc: 0.8030 | test_acc: 0.7980 | Time: 66.0635 s
# Training using original train data using batch size of 96 and total batches of 417
# Training using augmented train data using batch size of 96 and total batches of 625
# >>> Epoch [18/50]
# train_loss: 1.5145 | train_acc: 0.9062 | val_loss: 1.6391 | val_acc: 0.7972 | test_acc: 0.7978 | Time: 64.7611 s
# Training using original train data using batch size of 96 and total batches of 417
# Training using augmented train data using batch size of 96 and total batches of 625
# >>> Epoch [19/50]
# train_loss: 1.5425 | train_acc: 0.9091 | val_loss: 1.6381 | val_acc: 0.8013 | test_acc: 0.7946 | Time: 65.7897 s
# Training using original train data using batch size of 96 and total batches of 417
# Training using augmented train data using batch size of 96 and total batches of 625
# >>> Epoch [20/50]
# train_loss: 1.5230 | train_acc: 0.9508 | val_loss: 1.6377 | val_acc: 0.7987 | test_acc: 0.7964 | Time: 64.7311 s
# Training using original train data using batch size of 96 and total batches of 417
# Training using augmented train data using batch size of 96 and total batches of 627
# >>> Epoch [21/50]
# train_loss: 1.5418 | train_acc: 0.8824 | val_loss: 1.6359 | val_acc: 0.8005 | test_acc: 0.8012 | Time: 65.8847 s
# Training using original train data using batch size of 96 and total batches of 417
# Training using augmented train data using batch size of 96 and total batches of 627
# >>> Epoch [22/50]
# train_loss: 1.6821 | train_acc: 0.7500 | val_loss: 1.6351 | val_acc: 0.8029 | test_acc: 0.7975 | Time: 64.7599 s
# Training using original train data using batch size of 96 and total batches of 417
# Training using augmented train data using batch size of 96 and total batches of 627
# >>> Epoch [23/50]
# train_loss: 1.5141 | train_acc: 0.9551 | val_loss: 1.6350 | val_acc: 0.8047 | test_acc: 0.7980 | Time: 65.7117 s
# Training using original train data using batch size of 96 and total batches of 417
# Training using augmented train data using batch size of 96 and total batches of 626
# >>> Epoch [24/50]
# train_loss: 1.5591 | train_acc: 0.9286 | val_loss: 1.6389 | val_acc: 0.8089 | test_acc: 0.7985 | Time: 65.0446 s
# Training using original train data using batch size of 96 and total batches of 417
# Training using augmented train data using batch size of 96 and total batches of 624
# >>> Epoch [25/50]
# train_loss: 1.5229 | train_acc: 0.8852 | val_loss: 1.6377 | val_acc: 0.8024 | test_acc: 0.7974 | Time: 65.8484 s
# Training using original train data using batch size of 96 and total batches of 417
# Training using augmented train data using batch size of 96 and total batches of 626
# >>> Epoch [26/50]
# train_loss: 1.5280 | train_acc: 0.9583 | val_loss: 1.6361 | val_acc: 0.8010 | test_acc: 0.7986 | Time: 64.8228 s
# Training using original train data using batch size of 96 and total batches of 417
# Training using augmented train data using batch size of 96 and total batches of 626
# >>> Epoch [27/50]
# train_loss: 1.5352 | train_acc: 0.9500 | val_loss: 1.6336 | val_acc: 0.8034 | test_acc: 0.8009 | Time: 65.5681 s
# Training using original train data using batch size of 96 and total batches of 417
# Training using augmented train data using batch size of 96 and total batches of 625
# >>> Epoch [28/50]
# train_loss: 1.5177 | train_acc: 0.9286 | val_loss: 1.6317 | val_acc: 0.8060 | test_acc: 0.8004 | Time: 64.3195 s
# Training using original train data using batch size of 96 and total batches of 417
# Training using augmented train data using batch size of 96 and total batches of 627
# >>> Epoch [29/50]
# train_loss: 1.5248 | train_acc: 0.9474 | val_loss: 1.6378 | val_acc: 0.8044 | test_acc: 0.7987 | Time: 65.6576 s
# Training using original train data using batch size of 96 and total batches of 417
# Training using augmented train data using batch size of 96 and total batches of 628
# >>> Epoch [30/50]
# train_loss: 1.5188 | train_acc: 0.9184 | val_loss: 1.6413 | val_acc: 0.7956 | test_acc: 0.7934 | Time: 64.5859 s
# Training using original train data using batch size of 96 and total batches of 417
# Training using augmented train data using batch size of 96 and total batches of 626
# >>> Epoch [31/50]
# train_loss: 1.5178 | train_acc: 0.9574 | val_loss: 1.6371 | val_acc: 0.8102 | test_acc: 0.7987 | Time: 66.1391 s
# Training using original train data using batch size of 96 and total batches of 417
# Training using augmented train data using batch size of 96 and total batches of 627
# >>> Epoch [32/50]
# train_loss: 1.5459 | train_acc: 0.9333 | val_loss: 1.6345 | val_acc: 0.7999 | test_acc: 0.8002 | Time: 64.5441 s
# Training using original train data using batch size of 96 and total batches of 417
# Training using augmented train data using batch size of 96 and total batches of 627
# >>> Epoch [33/50]
# train_loss: 1.5258 | train_acc: 0.9298 | val_loss: 1.6367 | val_acc: 0.8008 | test_acc: 0.7971 | Time: 66.0718 s
# Training using original train data using batch size of 96 and total batches of 417
# Training using augmented train data using batch size of 96 and total batches of 627
# >>> Epoch [34/50]
# train_loss: 1.5517 | train_acc: 0.9355 | val_loss: 1.6415 | val_acc: 0.8006 | test_acc: 0.8006 | Time: 65.0003 s
# Training using original train data using batch size of 96 and total batches of 417
# Training using augmented train data using batch size of 96 and total batches of 626
# >>> Epoch [35/50]
# train_loss: 1.5136 | train_acc: 0.9512 | val_loss: 1.6375 | val_acc: 0.8012 | test_acc: 0.7972 | Time: 65.7281 s
# Training using original train data using batch size of 96 and total batches of 417
# Training using augmented train data using batch size of 96 and total batches of 625
# >>> Epoch [36/50]
# train_loss: 1.5432 | train_acc: 0.9200 | val_loss: 1.6390 | val_acc: 0.8021 | test_acc: 0.7968 | Time: 64.9408 s
# Training using original train data using batch size of 96 and total batches of 417
# Training using augmented train data using batch size of 96 and total batches of 625
# >>> Epoch [37/50]
# train_loss: 1.5092 | train_acc: 0.9574 | val_loss: 1.6373 | val_acc: 0.8040 | test_acc: 0.7959 | Time: 66.2188 s
# Training using original train data using batch size of 96 and total batches of 417
# Training using augmented train data using batch size of 96 and total batches of 626
# >>> Epoch [38/50]
# train_loss: 1.5657 | train_acc: 0.8824 | val_loss: 1.6396 | val_acc: 0.7967 | test_acc: 0.8010 | Time: 64.8162 s
# Training using original train data using batch size of 96 and total batches of 417
# Training using augmented train data using batch size of 96 and total batches of 626
# >>> Epoch [39/50]
# train_loss: 1.5229 | train_acc: 0.9394 | val_loss: 1.6421 | val_acc: 0.7970 | test_acc: 0.7935 | Time: 66.0267 s
# Training using original train data using batch size of 96 and total batches of 417
# Training using augmented train data using batch size of 96 and total batches of 627
# >>> Epoch [40/50]
# train_loss: 1.4821 | train_acc: 1.0000 | val_loss: 1.6444 | val_acc: 0.7958 | test_acc: 0.7867 | Time: 64.4144 s
# Training using original train data using batch size of 96 and total batches of 417
# Training using augmented train data using batch size of 96 and total batches of 627
# >>> Epoch [41/50]
# train_loss: 1.4789 | train_acc: 1.0000 | val_loss: 1.6348 | val_acc: 0.8060 | test_acc: 0.7990 | Time: 65.7634 s
# Training using original train data using batch size of 96 and total batches of 417
# Training using augmented train data using batch size of 96 and total batches of 626
# >>> Epoch [42/50]
# train_loss: 1.5401 | train_acc: 0.9000 | val_loss: 1.6398 | val_acc: 0.7968 | test_acc: 0.7933 | Time: 64.5177 s
# Training using original train data using batch size of 96 and total batches of 417
# Training using augmented train data using batch size of 96 and total batches of 625
# >>> Epoch [43/50]
# train_loss: 1.5228 | train_acc: 0.9302 | val_loss: 1.6356 | val_acc: 0.8026 | test_acc: 0.7965 | Time: 66.1147 s
# Training using original train data using batch size of 96 and total batches of 417
# Training using augmented train data using batch size of 96 and total batches of 624
# >>> Epoch [44/50]
# train_loss: 1.5350 | train_acc: 0.9239 | val_loss: 1.6402 | val_acc: 0.7983 | test_acc: 0.7974 | Time: 65.0607 s
# Training using original train data using batch size of 96 and total batches of 417
# Training using augmented train data using batch size of 96 and total batches of 626
# >>> Epoch [45/50]
# train_loss: 1.5564 | train_acc: 0.9231 | val_loss: 1.6344 | val_acc: 0.8017 | test_acc: 0.7972 | Time: 65.5561 s
# Training using original train data using batch size of 96 and total batches of 417
# Training using augmented train data using batch size of 96 and total batches of 626
# >>> Epoch [46/50]
# train_loss: 1.5135 | train_acc: 0.9540 | val_loss: 1.6346 | val_acc: 0.8051 | test_acc: 0.7970 | Time: 64.6603 s
# Training using original train data using batch size of 96 and total batches of 417
# Training using augmented train data using batch size of 96 and total batches of 627
# >>> Epoch [47/50]
# train_loss: 2.3953 | train_acc: 0.0000 | val_loss: 1.6335 | val_acc: 0.8037 | test_acc: 0.7950 | Time: 65.8973 s
# Training using original train data using batch size of 96 and total batches of 417
# Training using augmented train data using batch size of 96 and total batches of 626
# >>> Epoch [48/50]
# train_loss: 1.5535 | train_acc: 0.9079 | val_loss: 1.6436 | val_acc: 0.7947 | test_acc: 0.7882 | Time: 64.5575 s
# Training using original train data using batch size of 96 and total batches of 417
# Training using augmented train data using batch size of 96 and total batches of 626
# >>> Epoch [49/50]
# train_loss: 1.5439 | train_acc: 0.9041 | val_loss: 1.6410 | val_acc: 0.7975 | test_acc: 0.7948 | Time: 66.4043 s
# Fit completed in 68.6385 seconds
# 3383.195059776306

# %%
print(cnn.model_params['layers']['conv_layer_1'])
# Out:
# Tensor("Layers/conv_layer_1/conv_layer_1:0", shape=(?, 32, 32, 32), dtype=float32, device=/device:GPU:0)

# %%
input_image = cifar10.train.images[7:8, :]
cnn.plot_layers(input_image, 'conv_layer_1')
cnn.plot_layers(input_image, 'conv_layer_2')
cnn.plot_layers(input_image, 'conv_layer_3')
# Out:
# (32, 32, 32)
# (16, 16, 128)
# (8, 8, 512)
# True

# %%
input_image = cifar10.train.images[1:2, :]
cnn.plot_layers(input_image, 'conv_layer_1')
cnn.plot_layers(input_image, 'conv_layer_2')
cnn.plot_layers(input_image, 'conv_layer_3')
# Out:
# (32, 32, 32)
# (16, 16, 128)
# (8, 8, 512)
# True

# %% [markdown]
# ### Step 2.4: Make the predictions

# %%
prediction_numbers = cnn.predict(cifar10.test.images)
prediction_classes = []
num_test_images = cifar10.test.images.shape[0]
for i in range(num_test_images):
    prediction_classes.append(cifar10.classes[int(prediction_numbers[i])])

# %%
cifar10.plot_images(cifar10.test.images[:50], cifar10.test.class_names[:50], cls_pred=prediction_classes[:50], 
                    nrows=5, ncols=10, fig_size=(20,50), fontsize=30, convert=False)
# Out:
# True

# %% [markdown]
# ### Step 2.5: Print the results

# %%
test_accuracy = cnn.score(cifar10.test.images, cifar10.test.class_labels)
print('Accuracy of the linear classifier on test dataset: %.4f' %test_accuracy)
# Out:
# Accuracy of the linear classifier on test dataset: 0.7948

# %%
cnn.print_classification_results(cifar10.test.images, cifar10.test.one_hot_labels, cifar10.test.class_labels,
                                 test_class_names=cifar10.classes, normalize=True)
# Out:
# Confusion matrix, without normalization
# [[839  11  22  19  10   6   6  13  54  20]
#  [ 11 916   0   5   2   5   4   3  17  37]
#  [ 61   5 665  48  61  56  61  33   5   5]
#  [ 19  10  46 604  41 154  61  41  14  10]
#  [ 16   2  54  42 724  37  54  62   9   0]
#  [  7   8  30 121  31 736  21  40   2   4]
#  [  4   8  25  42  16  15 879   4   4   3]
#  [  7   3  17  27  29  28  10 875   1   3]
#  [ 41  20  11   4   4   4   6   7 888  15]
#  [ 27  78   9   9   4   5  12  13  21 822]]
# Normalized confusion matrix
# [[ 0.839  0.011  0.022  0.019  0.01   0.006  0.006  0.013  0.054  0.02 ]
#  [ 0.011  0.916  0.     0.005  0.002  0.005  0.004  0.003  0.017  0.037]
#  [ 0.061  0.005  0.665  0.048  0.061  0.056  0.061  0.033  0.005  0.005]
#  [ 0.019  0.01   0.046  0.604  0.041  0.154  0.061  0.041  0.014  0.01 ]
#  [ 0.016  0.002  0.054  0.042  0.724  0.037  0.054  0.062  0.009  0.   ]
#  [ 0.007  0.008  0.03   0.121  0.031  0.736  0.021  0.04   0.002  0.004]
#  [ 0.004  0.008  0.025  0.042  0.016  0.015  0.879  0.004  0.004  0.003]
#  [ 0.007  0.003  0.017  0.027  0.029  0.028  0.01   0.875  0.001  0.003]
#  [ 0.041  0.02   0.011  0.004  0.004  0.004  0.006  0.007  0.888  0.015]
#  [ 0.027  0.078  0.009  0.009  0.004  0.005  0.012  0.013  0.021  0.822]]
# Detailed classification report
#              precision    recall  f1-score   support
#
#    airplane       0.81      0.84      0.83      1000
#  automobile       0.86      0.92      0.89      1000
#        bird       0.76      0.67      0.71      1000
#         cat       0.66      0.60      0.63      1000
#        deer       0.79      0.72      0.75      1000
#         dog       0.70      0.74      0.72      1000
#        frog       0.79      0.88      0.83      1000
#       horse       0.80      0.88      0.84      1000
#        ship       0.87      0.89      0.88      1000
#       truck       0.89      0.82      0.86      1000
#
# avg / total       0.79      0.79      0.79     10000

# %% [markdown]
# ### Step 2.6: Plot results

# %%
cnn.plot_loss()
# Out:
# True

# %%
cnn.plot_accuracy()
# Out:
# True

# %% [markdown]
# ## Step 3: Write to file

# %%
def output_HTML(read_file, output_file):
    from nbconvert import HTMLExporter
    import codecs
    import nbformat
    exporter = HTMLExporter()
    output_notebook = nbformat.read(read_file, as_version=4)
    print()
    output, resources = exporter.from_notebook_node(output_notebook)
    codecs.open(output_file, 'w', encoding='utf-8').write(output)

# %%
# %%javascript
# var notebook = IPython.notebook
# notebook.save_notebook()

# %%
# %%javascript
# var kernel = IPython.notebook.kernel;
# var thename = window.document.getElementById("notebook_name").innerHTML;
# var command = "theNotebook = " + "'"+thename+"'";
# kernel.execute(command);

# %%
current_file = './' + theNotebook + '.ipynb'
output_file = log_dir + str(file_no).zfill(3) + '_exp_no_' + str(exp_no).zfill(3) + '_' + theNotebook + '.html'
print('Current file: ' + str(current_file))
print('Output file: ' + str(output_file))
file_utils.mkdir_p(log_dir) 
output_HTML(current_file, output_file)
# Out:
# Current file: ./105_Tf_CNN_Classifier_Raw_features_CIFAR_10.ipynb
# Output file: ../logs/cifar10/105_tf_cnn_raw/exp_no_002/105_exp_no_002_105_Tf_CNN_Classifier_Raw_features_CIFAR_10.html

# %% [markdown]
# ### Step 2.7: Close the session

# %%
cnn.close()
